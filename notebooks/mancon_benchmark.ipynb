# %%
# Imports

# To install contradictory_claims, please ensure that the package is pip installed in development from source.
# 
# $ cd drug-lit-conradictory-claims
# $ pip install -e .

import os

import contradictory_claims as cc
import pandas as pd
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, confusion_matrix
from transformers import AutoTokenizer

# %%
mancon_eval_data = cc.data.make_dataset.create_mancon_sent_pairs_from_xml('../input/manconcorpus/ManConCorpus.xml', 
                                                                          '../input/manconcorpus-sent-pairs/manconcorpus_sent_pairs_v2.tsv',
                                                                          '../input/manconcorpus/manconcorpus_benchmark_eval_data.tsv')

# %%
mancon_eval_data
# Out:
#                                                  text2     annotation  \
# 0    Supplementation during pregnancy with a medica...     entailment
# 1    Oral L-arginine supplementation did not reduce...  contradiction
# 2    L-Arginine load in pregnant women is associate...  contradiction
# 3    We conclude that in women with preeclampsia, p...     entailment
# 4    Blood pressure and kidney function improve mar...     entailment
# ..                                                 ...            ...
# 254  These findings further demonstrated that immun...     entailment
# 255  These results suggest that HLA-DR4 antigen may...     entailment
# 256  However, this and other studies continue to im...     entailment
# 257  In the IDC group, the frequency of human leuko...  contradiction
# 258  These data suggest that variation in class II ...     entailment
#
#                                                  text1
# 0    In women with pre-eclampsia, does treatment wi...
# ...
